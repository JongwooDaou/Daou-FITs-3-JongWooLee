# %% [markdown]
# <a href="https://colab.research.google.com/github/JongwooDaou/Daou-FITs-3-JongWooLee/blob/%EC%8B%A4%EC%8A%B5/%5BCS%5D20250110_%EC%8B%A4%EC%8A%B532%EB%B2%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ngrok 설치, streamlit 설치

# %%
# !pip install pyngrok
# !pip install streamlit

# %% [markdown]
# 토큰 설정

# %%
# !ngrok authtoken **TOKEN**
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# 파일 생성
# %%writefile app.py
import streamlit as st
import pandas as pd

st.title('고객 이탈 예측')

st.subheader('데이터셋을 업로드하세요')
upload_file = st.file_uploader("CSV 파일을 업로드", type=["CSV"])

if upload_file is not None:
    data = pd.read_csv(upload_file)
    st.write(data.head())
# Out:
# Overwriting app.py

# %% [markdown]
# streamlit 실행

# %%
# !streamlit run app.py &>/dev/null&

# %% [markdown]
# 주소 forwarding

# %%
from pyngrok import ngrok


# ngrok을 사용하여 포트 8501에 대한 외부 URL 생성
public_url = ngrok.connect(addr='8501')
public_url
# Out:
# <NgrokTunnel: "https://80d6-34-90-61-118.ngrok-free.app" -> "http://localhost:8501">

# %% [markdown]
# ![스크린샷 2025-01-10 153753.png](data:image/png;base64,...)
